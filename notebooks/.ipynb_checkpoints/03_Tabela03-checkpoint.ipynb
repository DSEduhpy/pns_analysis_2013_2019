# %% [markdown]
# 📘 Notebook – Tabela 3
#
# Distribuição relativa das mulheres por faixa etária segundo realização de exames preventivos
# PNS 2013 e 2019
# Mulheres com 25 anos ou mais

# %% [markdown]
# 🔹 Objetivo analítico
#
# Construir a Tabela 3, apresentando a distribuição percentual de mulheres segundo faixas etárias e realização de exames preventivos:
#
# Exame preventivo do colo do útero (Papanicolau)
#
# Mamografia
#
# A tabela segue rigorosamente o padrão metodológico das Tabelas 1 e 2, utilizando:
#
# Variáveis gold já persistidas (preventivo_fez, mamografia_fez)
#
# Percentuais relativos (%)
#
# Total por faixa etária igual a 100%

# %% [markdown]
# 🔹 Setup do ambiente

# %%
import pandas as pd
import numpy as np
import sys
from pathlib import Path


sys.path.append(str(Path("..").resolve()))
from service.pns_service import get_dataframe


pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %% [markdown]
# 🔹 Definição das faixas etárias (critério analítico)
#
# As faixas etárias seguem o padrão clássico da literatura epidemiológica e do exemplo de referência:

# %%
bins = [25, 35, 45, 55, 65, np.inf]
labels = [
"25–34 anos",
"35–44 anos",
"45–54 anos",
"55–64 anos",
"65 anos ou mais"
]

# %% [markdown]
# 🔹 Carregamento dos dados (gold)

# %%
variables = [
"idade",
"preventivo_fez",
"mamografia_fez"
]


sources = ["2013", "2019"]


df = get_dataframe(
variables=variables,
sources=sources,
filters={"sexo": "2", "idade": {"operador": ">=", "valor": "25"}}
)
# Out:
# Erro ao executar query no BigQuery:
# Are you sure you are using the right `billing_project_id`?
# You must use the Project ID available in your Google Cloud console home page at https://console.cloud.google.com/home/dashboard
# If you still don't have a Google Cloud Project, you have to create one.
# You can set one up by following these steps:
# 1. Go to this link https://console.cloud.google.com/projectselector2/home/dashboard
# 2. Agree with Terms of Service if asked
# 3. Click in Create Project
# 4. Put a cool name in your project
# 5. Hit create
# 6. Rerun this command with the flag `reauth=True`.
#    Like `read_table('br_ibge_pib', 'municipios', billing_project_id=<YOUR_PROJECT_ID>, reauth=True)`
# Erro ao buscar e salvar dados para origem 2013:
# Are you sure you are using the right `billing_project_id`?
# You must use the Project ID available in your Google Cloud console home page at https://console.cloud.google.com/home/dashboard
# If you still don't have a Google Cloud Project, you have to create one.
# You can set one up by following these steps:
# 1. Go to this link https://console.cloud.google.com/projectselector2/home/dashboard
# 2. Agree with Terms of Service if asked
# 3. Click in Create Project
# 4. Put a cool name in your project
# 5. Hit create
# 6. Rerun this command with the flag `reauth=True`.
#    Like `read_table('br_ibge_pib', 'municipios', billing_project_id=<YOUR_PROJECT_ID>, reauth=True)`
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas_gbq\query.py:85, in try_query(connector, query_fn)
#      84     logger.debug("Requesting query... ")
# ---> 85     return query_fn()
#      86 except concurrent.futures.TimeoutError as ex:
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\cloud\bigquery\client.py:3662, in Client.query_and_wait(self, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
#    3602 """Run the query, wait for it to finish, and return the results.
#    3603
#    3604 Args:
#    (...)   3660         class.
#    3661 """
# -> 3662 return self._query_and_wait_bigframes(
#    3663     query,
#    3664     job_config=job_config,
#    3665     location=location,
#    3666     project=project,
#    3667     api_timeout=api_timeout,
#    3668     wait_timeout=wait_timeout,
#    3669     retry=retry,
#    3670     job_retry=job_retry,
#    3671     page_size=page_size,
#    3672     max_results=max_results,
#    3673 )
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\cloud\bigquery\client.py:3708, in Client._query_and_wait_bigframes(self, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results, callback)
#    3704 job_config = _job_helpers.job_config_with_defaults(
#    3705     job_config, self._default_query_job_config
#    3706 )
# -> 3708 return _job_helpers.query_and_wait(
#    3709     self,
#    3710     query,
#    3711     job_config=job_config,
#    3712     location=location,
#    3713     project=project,
#    3714     api_timeout=api_timeout,
#    3715     wait_timeout=wait_timeout,
#    3716     retry=retry,
#    3717     job_retry=job_retry,
#    3718     page_size=page_size,
#    3719     max_results=max_results,
#    3720     callback=callback,
#    3721 )
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\cloud\bigquery\_job_helpers.py:627, in query_and_wait(client, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results, callback)
#     626 if job_retry is not None:
# --> 627     return job_retry(do_query)()
#     628 else:
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\cloud\bigquery\_job_helpers.py:545, in query_and_wait.<locals>.do_query()
#     544 if retry is not None:
# --> 545     response = retry(client._call_api)(
#     546         retry=None,  # We're calling the retry decorator ourselves.
#     547         span_name="BigQuery.query",
#     548         span_attributes=span_attributes,
#     549         method="POST",
#     550         path=path,
#     551         data=request_body,
#     552         timeout=api_timeout,
#     553     )
#     554 else:
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\cloud\bigquery\client.py:861, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     858     with create_span(
#     859         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     860     ):
# --> 861         return call()
#     863 return call()
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\cloud\_http\__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#
# Forbidden: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/fabled-mystery-463511-i1/queries?prettyPrint=false: Access Denied: Project fabled-mystery-463511-i1: User does not have bigquery.jobs.create permission in project fabled-mystery-463511-i1.
#
# The above exception was the direct cause of the following exception:
#
# GenericGBQException                       Traceback (most recent call last)
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\basedosdados\download\download.py:97, in read_sql(query, billing_project_id, from_file, reauth, use_bqstorage_api)
#      90     bigquery_storage_v1.client.BigQueryReadClient.read_rows = (
#      91         partialmethod(
#      92             bigquery_storage_v1.client.BigQueryReadClient.read_rows,
#      93             timeout=3600 * 2,
#      94         )  # type: ignore
#      95     )
# ---> 97     return read_gbq(
#      98         query,
#      99         project_id=billing_project_id,
#     100         use_bqstorage_api=use_bqstorage_api,
#     101         credentials=_credentials(from_file=from_file, reauth=reauth),
#     102     )  # type: ignore
#     103 except GenericGBQException as e:
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas_gbq\gbq.py:320, in read_gbq(query_or_table, project_id, index_col, columns, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, verbose, private_key, progress_bar_type, dtypes, auth_redirect_uri, client_id, client_secret, col_order, bigquery_client)
#     319 if _is_query(query_or_table):
# --> 320     final_df = connector.run_query(
#     321         query_or_table,
#     322         configuration=configuration,
#     323         max_results=max_results,
#     324         progress_bar_type=progress_bar_type,
#     325         dtypes=dtypes,
#     326     )
#     327 else:
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas_gbq\gbq_connector.py:217, in GbqConnector.run_query(self, query, max_results, progress_bar_type, **kwargs)
#     216 if FEATURES.bigquery_has_query_and_wait:
# --> 217     rows_iter = pandas_gbq.query.query_and_wait_via_client_library(
#     218         self,
#     219         self.client,
#     220         query,
#     221         location=self.location,
#     222         project_id=self.project_id,
#     223         job_config=job_config,
#     224         max_results=max_results,
#     225         timeout_ms=timeout_ms,
#     226     )
#     227 else:
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas_gbq\query.py:198, in query_and_wait_via_client_library(connector, client, query, job_config, location, project_id, max_results, timeout_ms)
#     187 def query_and_wait_via_client_library(
#     188     connector,
#     189     client: bigquery.Client,
#    (...)    196     timeout_ms: Optional[int],
#     197 ):
# --> 198     rows_iter = try_query(
#     199         connector,
#     200         functools.partial(
#     201             client.query_and_wait,
#     202             query,
#     203             job_config=job_config,
#     204             location=location,
#     205             project=project_id,
#     206             max_results=max_results,
#     207             wait_timeout=timeout_ms / 1000.0 if timeout_ms else None,
#     208         ),
#     209     )
#     210     logger.debug("Query done.\n")
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas_gbq\query.py:99, in try_query(connector, query_fn)
#      98 except connector.http_error as ex:
# ---> 99     connector.process_http_error(ex)
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas_gbq\gbq_connector.py:151, in GbqConnector.process_http_error(ex)
#     147 @staticmethod
#     148 def process_http_error(ex):
#     149     # See `BigQuery Troubleshooting Errors
#     150     # <https://cloud.google.com/bigquery/troubleshooting-errors>`__
# --> 151     raise pandas_gbq.exceptions.translate_exception(ex) from ex
#
# GenericGBQException: Reason: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/fabled-mystery-463511-i1/queries?prettyPrint=false: Access Denied: Project fabled-mystery-463511-i1: User does not have bigquery.jobs.create permission in project fabled-mystery-463511-i1.
#
# The above exception was the direct cause of the following exception:
#
# BaseDosDadosAccessDeniedException         Traceback (most recent call last)
# Cell In[6], line 11
#       1 variables = [
#       2 "idade",
#       3 "preventivo_quando",
#       4 "mamografia_quando"
#       5 ]
#       8 sources = ["2013", "2019"]
# ---> 11 df = get_dataframe(
#      12 variables=variables,
#      13 sources=sources,
#      14 filters={"sexo": "2", "idade": {"operador": ">=", "valor": "25"}}
#      15 )
#
# File ~\pns\service\pns_service.py:130, in get_dataframe(variables, sources, filters)
#     128 # 1. Garantir que os dados físicos estejam no cache (pode disparar ingestão)
#     129 if physical_vars:
# --> 130     dao_ensure_data(semantic_variables=physical_vars, sources=sources, filters=filters)
#     132 # 2. Carregar dados físicos do repositório local
#     133 # Incluir colunas dos filtros temporariamente para poder aplicá-los
#     134 filter_columns = set(filters.keys()) if filters else set()
#
# File ~\pns\dao\pns_dao.py:759, in ensure_data(semantic_variables, sources, filters)
#     750 """
#     751 Função de conveniência para garantir dados no repositório local.
#     752
#    (...)    756     filters: Filtros adicionais (opcional)
#     757 """
#     758 dao = get_dao()
# --> 759 dao.ensure_data(semantic_variables, sources, filters)
#
# File ~\pns\dao\pns_dao.py:113, in PNSDAO.ensure_data(self, semantic_variables, sources, filters)
#     111     log.info(f"Buscando dados para origem {source}...")
#     112     # Buscar apenas com variáveis que existem nesta origem
# --> 113     self._fetch_and_save_data(vars_for_source, source, filters)
#     114 else:
#     115     log.debug(f"Dados para origem {source} já estão no repositório local")
#
# File ~\pns\dao\pns_dao.py:242, in PNSDAO._fetch_and_save_data(self, semantic_variables, source, filters)
#     240 # 2. Executar no BigQuery
#     241 log.info(f"Executando query no BigQuery para origem {source}...")
# --> 242 df_physical = run_query(query)
#     244 if df_physical.empty:
#     245     log.warning(f"Nenhum dado retornado do BigQuery para origem {source}")
#
# File ~\pns\ingestion\basedosdados_client.py:49, in run_query(sql)
#      45 log.debug(f"Query SQL:\n{sql}")
#      47 try:
#      48     # Executar query via basedosdados
# ---> 49     df = bd.read_sql(sql, billing_project_id=BILLING_PROJECT_ID)
#      51     log.info(f"Query executada com sucesso. Retornados {len(df)} registros.")
#      52     log.debug(f"Colunas retornadas: {list(df.columns)}")
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\basedosdados\download\download.py:105, in read_sql(query, billing_project_id, from_file, reauth, use_bqstorage_api)
#     103 except GenericGBQException as e:
#     104     if "Reason: 403" in str(e):
# --> 105         raise BaseDosDadosAccessDeniedException from e
#     107     if re.match("Reason: 400 POST .* [Pp]roject[ ]*I[Dd]", str(e)):
#     108         raise BaseDosDadosInvalidProjectIDException from e
#
# BaseDosDadosAccessDeniedException:
# Are you sure you are using the right `billing_project_id`?
# You must use the Project ID available in your Google Cloud console home page at https://console.cloud.google.com/home/dashboard
# If you still don't have a Google Cloud Project, you have to create one.
# You can set one up by following these steps:
# 1. Go to this link https://console.cloud.google.com/projectselector2/home/dashboard
# 2. Agree with Terms of Service if asked
# 3. Click in Create Project
# 4. Put a cool name in your project
# 5. Hit create
# 6. Rerun this command with the flag `reauth=True`.
#    Like `read_table('br_ibge_pib', 'municipios', billing_project_id=<YOUR_PROJECT_ID>, reauth=True)`

# %% [markdown]
# 🔹 Criação da variável faixa etária

# %%
# Criação da variável faixa etária
bins = [25, 35, 45, 55, 65, np.inf]
labels = [
    "Entre 25 e 34 anos",
    "Entre 35 e 44 anos",
    "Entre 45 e 54 anos",
    "Entre 55 e 64 anos",
    "Mais de 65 anos"
]

df["faixa_etaria"] = pd.cut(
    df["idade"],
    bins=bins,
    labels=labels,
    right=False
)

# %% [markdown]
# 🔹 Função auxiliar para cálculo percentual por faixa etária

# %%
def tabela_faixa(df, col):
tab = (
df.groupby("faixa_etaria")[col]
.agg([
lambda x: (x.mean() * 100).round(1),
lambda x: (100 - x.mean() * 100).round(1)
])
)
tab.columns = ["Sim", "Não"]
tab["Total"] = 100.0
return tab

# %% [markdown]
# 🔹 Construção da Tabela 3 (por ano)

# %%
tabelas = {}


for ano in sorted(df["origem"].unique()):
df_ano = df[df["origem"] == ano]


tabela = pd.concat(
{
"Papanicolau": tabela_faixa(df_ano, "preventivo_fez"),
"Mamografia": tabela_faixa(df_ano, "mamografia_fez")
},
axis=1
)


tabelas[ano] = tabela

# %% [markdown]
# 🔹 Exibição final (formato artigo)

# %%
for ano, tabela in tabelas.items():
print(f"\nTabela 3 – Distribuição das mulheres por faixa etária segundo realização de exames (%), PNS {ano}")
display(tabela)

# %% [markdown]
# 📌 Nota metodológica
#
# O denominador de cada faixa etária corresponde ao total de mulheres naquela faixa;
#
# As categorias “Sim” e “Não” referem-se exclusivamente à realização do exame, conforme definição das variáveis gold;
#
# Os percentuais são calculados intra-faixa etária, totalizando 100% em cada linha;
#
# Não são realizadas imputações nem ponderações adicionais além do critério já consolidado nas Tabelas 1 e 2.
#
# Fonte: Elaboração própria a partir dos microdados da Pesquisa Nacional de Saúde (PNS 2013 e 2019), IBGE.
